# %%
import glob
import sys
import os
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import scipy as spy
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
from torch.utils.data.sampler import SubsetRandomSampler
import ssl
import pickle, json
import src.main as lc
import old_lc.main as olc
from src.models.AlexNet import AlexNet
import src.compression.deltaCompress as lc_compress
from src.models.AlexNet_LowRank import getBase, AlexNet_LowRank, load_sd_decomp
from src.utils.utils import evaluate_accuracy, lazy_restore, evaluate_compression

# %%
HDFP = "/volumes/Ultra Touch" # Load HHD

def data_loader():
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])

    trainset = datasets.MNIST(root='./data', train=True,
                                          download=True, transform=transform)
    # Reintroduce the 2000 datapoints model has not seen before.
    trainset.data = trainset.data.clone()[-2000:-1000]
    trainset.targets = trainset.targets.clone()[-2000:-1000]
    trainloader = torch.utils.data.DataLoader(trainset, batch_size = 32,
                                              shuffle=False, num_workers=2)

    testset = datasets.MNIST(root='./data', train=False,
                                         download=True, transform=transform)

    testset.data = trainset.data[-1000:]
    testset.targets = trainset.targets[-1000:]
    testloader = torch.utils.data.DataLoader(testset, batch_size = 32,
                                             shuffle=False, num_workers=2)
    
    testloader = torch.utils.data.DataLoader(testset, batch_size = 32,
                                             shuffle=False, num_workers=2)
    
    return trainloader, testloader

# %%
# Bypass using SSL unverified
ssl._create_default_https_context = ssl._create_unverified_context
# MNIST dataset 
train_loader, test_loader = data_loader()

# %%
SAVE_LOC = HDFP + "/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch"
if not os.path.exists(SAVE_LOC):
    os.makedirs(SAVE_LOC)

SAVE_LOC_OLC = HDFP + "/lobranch-snapshot/diffbitwidth-adaptive-rank/old-lc"
if not os.path.exists(SAVE_LOC_OLC):
    os.makedirs(SAVE_LOC_OLC)

# %%
DECOMPOSED_LAYERS = ["classifier.1.weight", "classifier.4.weight"]
RANK = -1
SCALING = -1
BRANCH_ACC = "0.8072"

# Set up weights for original AlexNet model
original = AlexNet()
model_original = AlexNet()

# Load from "branch point"
BRANCH_LOC = HDFP + "/lobranch-snapshot/branchpoints/branch_{}.pt".format(BRANCH_ACC)
original.load_state_dict(torch.load(BRANCH_LOC))
model_original.load_state_dict(torch.load(BRANCH_LOC))

w, b = getBase(model_original)
model = AlexNet_LowRank(w, b, rank = RANK)
load_sd_decomp(torch.load(BRANCH_LOC), model, DECOMPOSED_LAYERS)
learning_rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 7
#       4 BRANCH_ACC = "0.8072"
#       6 # Set up weights for original AlexNet model
# ----> 7 original = AlexNet()
#       8 model_original = AlexNet()
#      10 # Load from "branch point"
#
# NameError: name 'AlexNet' is not defined

# %%
delta_normal_max = []
delta_normal_min = []
delta_decomposed_max = []
delta_decomposed_min = []
full_accuracy = []
decomposed_full_accuracy = []
restored_accuracy = []
lc_accuracy = []
current_iter = 0
current_set = 0

current_iter_old_lc = 0
current_set_old_lc = 0

acc = lambda x, y : (torch.max(x, 1)[1] == y).sum().item() / y.size(0)

for epch in range(20):
    for i, data in enumerate(train_loader, 0):
        print("Epoch: {}, Iteration: {}".format(epch, i))
        
        set_path = "/set_{}".format(current_set)
        if not os.path.exists(SAVE_LOC + set_path):
            os.makedirs(SAVE_LOC + set_path)

        if i == 0 and epch == 0: # first iteration, create baseline model
            base, base_decomp = lc.extract_weights(model, SAVE_LOC + 
                                                       "/set_{}".format(current_set), DECOMPOSED_LAYERS)
        else:
            if i % 10 == 0: 
                # full snapshot!
                new_model = lazy_restore(base, base_decomp, bias, AlexNet(), 
                                          original.state_dict(), DECOMPOSED_LAYERS, rank = RANK, scaling = SCALING)
                
                original = new_model # Changing previous "original model" used to restore the loRA model.
                
                current_set += 1
                current_iter = 0

                set_path = "/set_{}".format(current_set)
                if not os.path.exists(SAVE_LOC + set_path):
                    os.makedirs(SAVE_LOC + set_path)
                
                # Rebuilding LoRA layers => reset model!
                w, b = getBase(original)
                model = AlexNet_LowRank(w, b, rank = RANK)
                optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)
                load_sd_decomp(original.state_dict(), model, DECOMPOSED_LAYERS)
                base, base_decomp = lc.extract_weights(model, SAVE_LOC + 
                                                       "/set_{}".format(current_set), DECOMPOSED_LAYERS)

            else:
                # Delta-compression 
                delta, decomp_delta, bias = lc.generate_delta(base, 
                                                                base_decomp, model.state_dict(), DECOMPOSED_LAYERS)
                compressed_delta, full_delta, compressed_dcomp_delta, full_dcomp_delta  = lc.compress_delta(delta, 
                                                                                                            decomp_delta)
                
                # Saving checkpoint
                lc.save_checkpoint(compressed_delta, compressed_dcomp_delta, bias, current_iter, SAVE_LOC + 
                                "/set_{}".format(current_set))
    
                base = np.add(base, full_delta) # Replace base with latest for delta to accumulate.
                base_decomp = np.add(full_dcomp_delta, base_decomp)

                current_iter += 1
            
        # ==========================
        # Saving using LC-Checkpoint
        # ==========================
                
        if i == 0 and epch == 0:
            cstate = model_original.state_dict()
            set_path = "/set_{}".format(current_set_old_lc)
            if not os.path.exists(SAVE_LOC_OLC + set_path):
                os.makedirs(SAVE_LOC_OLC + set_path)
            torch.save(cstate, SAVE_LOC_OLC + set_path + "/initial_model.pt")
            prev_state = olc.extract_weights(model_original)
        else:
            if i % 10 == 0:
                cstate = model_original.state_dict()
                current_set_old_lc += 1
                current_iter_old_lc = 0
                set_path = "/set_{}".format(current_set_old_lc)
                if not os.path.exists(SAVE_LOC_OLC + set_path):
                    os.makedirs(SAVE_LOC_OLC + set_path)
                torch.save(cstate, SAVE_LOC_OLC + set_path + "/initial_model.pt")
                prev_state = olc.extract_weights(model_original)
            else:
                cstate = model_original.state_dict()
                old_lc_delta, old_lc_bias, _ = olc.generate_delta(prev_state, cstate)
                olc_compressed_delta, update_prev = olc.compress_data(old_lc_delta, num_bits = 3)
                olc.save_checkpoint(SAVE_LOC_OLC + "/set_{}".format(current_set_old_lc), olc_compressed_delta, 
                                    old_lc_bias, epch, current_iter_old_lc)
                prev_state = np.add(prev_state, update_prev)
                current_iter_old_lc += 1
        
        # ==========================
        # Training on Low-Rank Model
        # ==========================

        # Get the inputs and labels
        inputs, labels = data

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward + backward + optimize
        outputs = model(inputs)
        loss = torch.nn.functional.cross_entropy(outputs,labels)
        loss.backward()
        optimizer.step()
            
        # ======================
        # Training on Full Model
        # ======================

        # Zero the parameter gradients
        optimizer_full.zero_grad()

        # Forward + backward + optimize
        outputs_full = model_original(inputs)
        loss_full = torch.nn.functional.cross_entropy(outputs_full,labels)
        loss_full.backward()
        optimizer_full.step()

        if i % 20 == 0:
            print("Training Accuracy | Decomposed: {}, Full : {}".format(acc(outputs, labels), 
                                                                         acc(outputs_full, labels)))

        if i != 0  and i % 5 == 0: # Evaluation on testing set
            full_accuracy.append(evaluate_accuracy(model_original, test_loader))
            decomposed_full_accuracy.append(evaluate_accuracy(model, test_loader))
            restored_model = lazy_restore(base, base_decomp, bias, AlexNet(), 
                                          original.state_dict(), DECOMPOSED_LAYERS, 
                                          rank = RANK, scaling = SCALING)
            restored_accuracy.append(evaluate_accuracy(restored_model, test_loader))
            restored_lc_model = AlexNet()
            restored_lc_model.load_state_dict(olc.restore_state_dict(prev_state, old_lc_bias, 
                                                                  restored_model.state_dict()))
            lc_accuracy.append(evaluate_accuracy(restored_lc_model, test_loader))
            print("Full accuracy: {}, LC accuracy: {}, Decomposed-Full accuracy: {}, Decomposed-Restored accuracy: {}".format(
                full_accuracy[-1], lc_accuracy[-1], decomposed_full_accuracy[-1], restored_accuracy[-1]))
# Out:
# Epoch: 0, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0/base_model.pt
# Training Accuracy | Decomposed: 0.75, Full : 0.78125
# Epoch: 0, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0
# Epoch: 0, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0
# Epoch: 0, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0
# Epoch: 0, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0
# Epoch: 0, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0
# model accuracy: 0.882
# model accuracy: 0.898
# model accuracy: 0.9
# model accuracy: 0.885
# Full accuracy: 0.882, LC accuracy: 0.885, Decomposed-Full accuracy: 0.898, Decomposed-Restored accuracy: 0.9
# Epoch: 0, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0
# Epoch: 0, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0
# Epoch: 0, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0
# Epoch: 0, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_0
# Epoch: 0, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1/base_model.pt
# model accuracy: 0.843
# model accuracy: 0.862
# model accuracy: 0.869
# model accuracy: 0.888
# Full accuracy: 0.843, LC accuracy: 0.888, Decomposed-Full accuracy: 0.862, Decomposed-Restored accuracy: 0.869
# Epoch: 0, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1
# Epoch: 0, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1
# Epoch: 0, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1
# Epoch: 0, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1
# Epoch: 0, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1
# model accuracy: 0.893
# model accuracy: 0.892
# model accuracy: 0.879
# model accuracy: 0.894
# Full accuracy: 0.893, LC accuracy: 0.894, Decomposed-Full accuracy: 0.892, Decomposed-Restored accuracy: 0.879
# Epoch: 0, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1
# Epoch: 0, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1
# Epoch: 0, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1
# Epoch: 0, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_1
# Epoch: 0, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2/base_model.pt
# Training Accuracy | Decomposed: 0.71875, Full : 0.75
# model accuracy: 0.788
# model accuracy: 0.874
# model accuracy: 0.899
# model accuracy: 0.857
# Full accuracy: 0.788, LC accuracy: 0.857, Decomposed-Full accuracy: 0.874, Decomposed-Restored accuracy: 0.899
# Epoch: 0, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2
# Epoch: 0, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2
# Epoch: 0, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2
# Epoch: 0, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2
# Epoch: 0, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2
# model accuracy: 0.906
# model accuracy: 0.894
# model accuracy: 0.903
# model accuracy: 0.883
# Full accuracy: 0.906, LC accuracy: 0.883, Decomposed-Full accuracy: 0.894, Decomposed-Restored accuracy: 0.903
# Epoch: 0, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2
# Epoch: 0, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2
# Epoch: 0, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2
# Epoch: 0, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_2
# Epoch: 0, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_3/base_model.pt
# model accuracy: 0.897
# model accuracy: 0.887
# model accuracy: 0.907
# model accuracy: 0.886
# Full accuracy: 0.897, LC accuracy: 0.886, Decomposed-Full accuracy: 0.887, Decomposed-Restored accuracy: 0.907
# Epoch: 0, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_3
# Epoch: 1, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4/base_model.pt
# Training Accuracy | Decomposed: 0.78125, Full : 0.78125
# Epoch: 1, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4
# Epoch: 1, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4
# Epoch: 1, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4
# Epoch: 1, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4
# Epoch: 1, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4
# model accuracy: 0.896
# model accuracy: 0.883
# model accuracy: 0.92
# model accuracy: 0.895
# Full accuracy: 0.896, LC accuracy: 0.895, Decomposed-Full accuracy: 0.883, Decomposed-Restored accuracy: 0.92
# Epoch: 1, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4
# Epoch: 1, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4
# Epoch: 1, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4
# Epoch: 1, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_4
# Epoch: 1, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5/base_model.pt
# model accuracy: 0.861
# model accuracy: 0.87
# model accuracy: 0.879
# model accuracy: 0.888
# Full accuracy: 0.861, LC accuracy: 0.888, Decomposed-Full accuracy: 0.87, Decomposed-Restored accuracy: 0.879
# Epoch: 1, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5
# Epoch: 1, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5
# Epoch: 1, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5
# Epoch: 1, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5
# Epoch: 1, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5
# model accuracy: 0.91
# model accuracy: 0.896
# model accuracy: 0.877
# model accuracy: 0.913
# Full accuracy: 0.91, LC accuracy: 0.913, Decomposed-Full accuracy: 0.896, Decomposed-Restored accuracy: 0.877
# Epoch: 1, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5
# Epoch: 1, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5
# Epoch: 1, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5
# Epoch: 1, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_5
# Epoch: 1, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6/base_model.pt
# Training Accuracy | Decomposed: 0.71875, Full : 0.78125
# model accuracy: 0.842
# model accuracy: 0.876
# model accuracy: 0.903
# model accuracy: 0.91
# Full accuracy: 0.842, LC accuracy: 0.91, Decomposed-Full accuracy: 0.876, Decomposed-Restored accuracy: 0.903
# Epoch: 1, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6
# Epoch: 1, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6
# Epoch: 1, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6
# Epoch: 1, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6
# Epoch: 1, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6
# model accuracy: 0.911
# model accuracy: 0.904
# model accuracy: 0.914
# model accuracy: 0.919
# Full accuracy: 0.911, LC accuracy: 0.919, Decomposed-Full accuracy: 0.904, Decomposed-Restored accuracy: 0.914
# Epoch: 1, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6
# Epoch: 1, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6
# Epoch: 1, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6
# Epoch: 1, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_6
# Epoch: 1, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_7/base_model.pt
# model accuracy: 0.913
# model accuracy: 0.909
# model accuracy: 0.91
# model accuracy: 0.917
# Full accuracy: 0.913, LC accuracy: 0.917, Decomposed-Full accuracy: 0.909, Decomposed-Restored accuracy: 0.91
# Epoch: 1, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_7
# Epoch: 2, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8/base_model.pt
# Training Accuracy | Decomposed: 0.78125, Full : 0.84375
# Epoch: 2, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8
# Epoch: 2, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8
# Epoch: 2, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8
# Epoch: 2, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8
# Epoch: 2, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8
# model accuracy: 0.905
# model accuracy: 0.913
# model accuracy: 0.917
# model accuracy: 0.912
# Full accuracy: 0.905, LC accuracy: 0.912, Decomposed-Full accuracy: 0.913, Decomposed-Restored accuracy: 0.917
# Epoch: 2, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8
# Epoch: 2, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8
# Epoch: 2, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8
# Epoch: 2, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_8
# Epoch: 2, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9/base_model.pt
# model accuracy: 0.891
# model accuracy: 0.879
# model accuracy: 0.892
# model accuracy: 0.909
# Full accuracy: 0.891, LC accuracy: 0.909, Decomposed-Full accuracy: 0.879, Decomposed-Restored accuracy: 0.892
# Epoch: 2, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9
# Epoch: 2, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9
# Epoch: 2, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9
# Epoch: 2, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9
# Epoch: 2, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9
# model accuracy: 0.923
# model accuracy: 0.914
# model accuracy: 0.902
# model accuracy: 0.917
# Full accuracy: 0.923, LC accuracy: 0.917, Decomposed-Full accuracy: 0.914, Decomposed-Restored accuracy: 0.902
# Epoch: 2, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9
# Epoch: 2, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9
# Epoch: 2, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9
# Epoch: 2, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_9
# Epoch: 2, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10/base_model.pt
# Training Accuracy | Decomposed: 0.78125, Full : 0.75
# model accuracy: 0.871
# model accuracy: 0.853
# model accuracy: 0.918
# model accuracy: 0.912
# Full accuracy: 0.871, LC accuracy: 0.912, Decomposed-Full accuracy: 0.853, Decomposed-Restored accuracy: 0.918
# Epoch: 2, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10
# Epoch: 2, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10
# Epoch: 2, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10
# Epoch: 2, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10
# Epoch: 2, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10
# model accuracy: 0.915
# model accuracy: 0.908
# model accuracy: 0.923
# model accuracy: 0.934
# Full accuracy: 0.915, LC accuracy: 0.934, Decomposed-Full accuracy: 0.908, Decomposed-Restored accuracy: 0.923
# Epoch: 2, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10
# Epoch: 2, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10
# Epoch: 2, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10
# Epoch: 2, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_10
# Epoch: 2, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_11/base_model.pt
# model accuracy: 0.924
# model accuracy: 0.911
# model accuracy: 0.912
# model accuracy: 0.929
# Full accuracy: 0.924, LC accuracy: 0.929, Decomposed-Full accuracy: 0.911, Decomposed-Restored accuracy: 0.912
# Epoch: 2, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_11
# Epoch: 3, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12/base_model.pt
# Training Accuracy | Decomposed: 0.875, Full : 0.8125
# Epoch: 3, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12
# Epoch: 3, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12
# Epoch: 3, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12
# Epoch: 3, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12
# Epoch: 3, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12
# model accuracy: 0.929
# model accuracy: 0.921
# model accuracy: 0.921
# model accuracy: 0.922
# Full accuracy: 0.929, LC accuracy: 0.922, Decomposed-Full accuracy: 0.921, Decomposed-Restored accuracy: 0.921
# Epoch: 3, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12
# Epoch: 3, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12
# Epoch: 3, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12
# Epoch: 3, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_12
# Epoch: 3, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13/base_model.pt
# model accuracy: 0.907
# model accuracy: 0.902
# model accuracy: 0.914
# model accuracy: 0.923
# Full accuracy: 0.907, LC accuracy: 0.923, Decomposed-Full accuracy: 0.902, Decomposed-Restored accuracy: 0.914
# Epoch: 3, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13
# Epoch: 3, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13
# Epoch: 3, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13
# Epoch: 3, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13
# Epoch: 3, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13
# model accuracy: 0.941
# model accuracy: 0.929
# model accuracy: 0.899
# model accuracy: 0.932
# Full accuracy: 0.941, LC accuracy: 0.932, Decomposed-Full accuracy: 0.929, Decomposed-Restored accuracy: 0.899
# Epoch: 3, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13
# Epoch: 3, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13
# Epoch: 3, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13
# Epoch: 3, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_13
# Epoch: 3, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14/base_model.pt
# Training Accuracy | Decomposed: 0.625, Full : 0.875
# model accuracy: 0.9
# model accuracy: 0.872
# model accuracy: 0.914
# model accuracy: 0.944
# Full accuracy: 0.9, LC accuracy: 0.944, Decomposed-Full accuracy: 0.872, Decomposed-Restored accuracy: 0.914
# Epoch: 3, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14
# Epoch: 3, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14
# Epoch: 3, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14
# Epoch: 3, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14
# Epoch: 3, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14
# model accuracy: 0.909
# model accuracy: 0.912
# model accuracy: 0.926
# model accuracy: 0.945
# Full accuracy: 0.909, LC accuracy: 0.945, Decomposed-Full accuracy: 0.912, Decomposed-Restored accuracy: 0.926
# Epoch: 3, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14
# Epoch: 3, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14
# Epoch: 3, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14
# Epoch: 3, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_14
# Epoch: 3, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_15/base_model.pt
# model accuracy: 0.936
# model accuracy: 0.899
# model accuracy: 0.917
# model accuracy: 0.934
# Full accuracy: 0.936, LC accuracy: 0.934, Decomposed-Full accuracy: 0.899, Decomposed-Restored accuracy: 0.917
# Epoch: 3, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_15
# Epoch: 4, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16/base_model.pt
# Training Accuracy | Decomposed: 0.78125, Full : 0.875
# Epoch: 4, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16
# Epoch: 4, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16
# Epoch: 4, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16
# Epoch: 4, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16
# Epoch: 4, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16
# model accuracy: 0.935
# model accuracy: 0.919
# model accuracy: 0.925
# model accuracy: 0.938
# Full accuracy: 0.935, LC accuracy: 0.938, Decomposed-Full accuracy: 0.919, Decomposed-Restored accuracy: 0.925
# Epoch: 4, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16
# Epoch: 4, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16
# Epoch: 4, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16
# Epoch: 4, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_16
# Epoch: 4, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17/base_model.pt
# model accuracy: 0.925
# model accuracy: 0.883
# model accuracy: 0.912
# model accuracy: 0.936
# Full accuracy: 0.925, LC accuracy: 0.936, Decomposed-Full accuracy: 0.883, Decomposed-Restored accuracy: 0.912
# Epoch: 4, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17
# Epoch: 4, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17
# Epoch: 4, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17
# Epoch: 4, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17
# Epoch: 4, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17
# model accuracy: 0.944
# model accuracy: 0.922
# model accuracy: 0.916
# model accuracy: 0.942
# Full accuracy: 0.944, LC accuracy: 0.942, Decomposed-Full accuracy: 0.922, Decomposed-Restored accuracy: 0.916
# Epoch: 4, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17
# Epoch: 4, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17
# Epoch: 4, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17
# Epoch: 4, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_17
# Epoch: 4, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18/base_model.pt
# Training Accuracy | Decomposed: 0.78125, Full : 0.8125
# model accuracy: 0.911
# model accuracy: 0.84
# model accuracy: 0.909
# model accuracy: 0.945
# Full accuracy: 0.911, LC accuracy: 0.945, Decomposed-Full accuracy: 0.84, Decomposed-Restored accuracy: 0.909
# Epoch: 4, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18
# Epoch: 4, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18
# Epoch: 4, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18
# Epoch: 4, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18
# Epoch: 4, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18
# model accuracy: 0.938
# model accuracy: 0.918
# model accuracy: 0.927
# model accuracy: 0.948
# Full accuracy: 0.938, LC accuracy: 0.948, Decomposed-Full accuracy: 0.918, Decomposed-Restored accuracy: 0.927
# Epoch: 4, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18
# Epoch: 4, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18
# Epoch: 4, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18
# Epoch: 4, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_18
# Epoch: 4, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_19/base_model.pt
# model accuracy: 0.932
# model accuracy: 0.919
# model accuracy: 0.921
# model accuracy: 0.941
# Full accuracy: 0.932, LC accuracy: 0.941, Decomposed-Full accuracy: 0.919, Decomposed-Restored accuracy: 0.921
# Epoch: 4, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_19
# Epoch: 5, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20/base_model.pt
# Training Accuracy | Decomposed: 0.84375, Full : 0.84375
# Epoch: 5, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20
# Epoch: 5, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20
# Epoch: 5, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20
# Epoch: 5, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20
# Epoch: 5, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20
# model accuracy: 0.946
# model accuracy: 0.916
# model accuracy: 0.93
# model accuracy: 0.944
# Full accuracy: 0.946, LC accuracy: 0.944, Decomposed-Full accuracy: 0.916, Decomposed-Restored accuracy: 0.93
# Epoch: 5, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20
# Epoch: 5, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20
# Epoch: 5, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20
# Epoch: 5, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_20
# Epoch: 5, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21/base_model.pt
# model accuracy: 0.927
# model accuracy: 0.895
# model accuracy: 0.902
# model accuracy: 0.942
# Full accuracy: 0.927, LC accuracy: 0.942, Decomposed-Full accuracy: 0.895, Decomposed-Restored accuracy: 0.902
# Epoch: 5, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21
# Epoch: 5, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21
# Epoch: 5, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21
# Epoch: 5, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21
# Epoch: 5, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21
# model accuracy: 0.952
# model accuracy: 0.92
# model accuracy: 0.913
# model accuracy: 0.943
# Full accuracy: 0.952, LC accuracy: 0.943, Decomposed-Full accuracy: 0.92, Decomposed-Restored accuracy: 0.913
# Epoch: 5, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21
# Epoch: 5, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21
# Epoch: 5, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21
# Epoch: 5, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_21
# Epoch: 5, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22/base_model.pt
# Training Accuracy | Decomposed: 0.75, Full : 0.9375
# model accuracy: 0.921
# model accuracy: 0.879
# model accuracy: 0.917
# model accuracy: 0.95
# Full accuracy: 0.921, LC accuracy: 0.95, Decomposed-Full accuracy: 0.879, Decomposed-Restored accuracy: 0.917
# Epoch: 5, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22
# Epoch: 5, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22
# Epoch: 5, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22
# Epoch: 5, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22
# Epoch: 5, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22
# model accuracy: 0.948
# model accuracy: 0.926
# model accuracy: 0.929
# model accuracy: 0.951
# Full accuracy: 0.948, LC accuracy: 0.951, Decomposed-Full accuracy: 0.926, Decomposed-Restored accuracy: 0.929
# Epoch: 5, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22
# Epoch: 5, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22
# Epoch: 5, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22
# Epoch: 5, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_22
# Epoch: 5, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_23/base_model.pt
# model accuracy: 0.946
# model accuracy: 0.923
# model accuracy: 0.929
# model accuracy: 0.941
# Full accuracy: 0.946, LC accuracy: 0.941, Decomposed-Full accuracy: 0.923, Decomposed-Restored accuracy: 0.929
# Epoch: 5, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_23
# Epoch: 6, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24/base_model.pt
# Training Accuracy | Decomposed: 0.875, Full : 0.875
# Epoch: 6, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24
# Epoch: 6, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24
# Epoch: 6, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24
# Epoch: 6, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24
# Epoch: 6, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24
# model accuracy: 0.957
# model accuracy: 0.918
# model accuracy: 0.927
# model accuracy: 0.954
# Full accuracy: 0.957, LC accuracy: 0.954, Decomposed-Full accuracy: 0.918, Decomposed-Restored accuracy: 0.927
# Epoch: 6, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24
# Epoch: 6, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24
# Epoch: 6, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24
# Epoch: 6, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_24
# Epoch: 6, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25/base_model.pt
# model accuracy: 0.925
# model accuracy: 0.899
# model accuracy: 0.908
# model accuracy: 0.935
# Full accuracy: 0.925, LC accuracy: 0.935, Decomposed-Full accuracy: 0.899, Decomposed-Restored accuracy: 0.908
# Epoch: 6, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25
# Epoch: 6, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25
# Epoch: 6, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25
# Epoch: 6, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25
# Epoch: 6, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25
# model accuracy: 0.943
# model accuracy: 0.93
# model accuracy: 0.922
# model accuracy: 0.948
# Full accuracy: 0.943, LC accuracy: 0.948, Decomposed-Full accuracy: 0.93, Decomposed-Restored accuracy: 0.922
# Epoch: 6, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25
# Epoch: 6, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25
# Epoch: 6, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25
# Epoch: 6, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_25
# Epoch: 6, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26/base_model.pt
# Training Accuracy | Decomposed: 0.71875, Full : 0.9375
# model accuracy: 0.942
# model accuracy: 0.894
# model accuracy: 0.928
# model accuracy: 0.954
# Full accuracy: 0.942, LC accuracy: 0.954, Decomposed-Full accuracy: 0.894, Decomposed-Restored accuracy: 0.928
# Epoch: 6, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26
# Epoch: 6, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26
# Epoch: 6, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26
# Epoch: 6, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26
# Epoch: 6, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26
# model accuracy: 0.962
# model accuracy: 0.929
# model accuracy: 0.931
# model accuracy: 0.962
# Full accuracy: 0.962, LC accuracy: 0.962, Decomposed-Full accuracy: 0.929, Decomposed-Restored accuracy: 0.931
# Epoch: 6, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26
# Epoch: 6, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26
# Epoch: 6, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26
# Epoch: 6, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_26
# Epoch: 6, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_27/base_model.pt
# model accuracy: 0.954
# model accuracy: 0.907
# model accuracy: 0.928
# model accuracy: 0.952
# Full accuracy: 0.954, LC accuracy: 0.952, Decomposed-Full accuracy: 0.907, Decomposed-Restored accuracy: 0.928
# Epoch: 6, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_27
# Epoch: 7, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28/base_model.pt
# Training Accuracy | Decomposed: 0.84375, Full : 0.96875
# Epoch: 7, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28
# Epoch: 7, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28
# Epoch: 7, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28
# Epoch: 7, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28
# Epoch: 7, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28
# model accuracy: 0.957
# model accuracy: 0.916
# model accuracy: 0.913
# model accuracy: 0.947
# Full accuracy: 0.957, LC accuracy: 0.947, Decomposed-Full accuracy: 0.916, Decomposed-Restored accuracy: 0.913
# Epoch: 7, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28
# Epoch: 7, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28
# Epoch: 7, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28
# Epoch: 7, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_28
# Epoch: 7, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29/base_model.pt
# model accuracy: 0.914
# model accuracy: 0.912
# model accuracy: 0.922
# model accuracy: 0.937
# Full accuracy: 0.914, LC accuracy: 0.937, Decomposed-Full accuracy: 0.912, Decomposed-Restored accuracy: 0.922
# Epoch: 7, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29
# Epoch: 7, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29
# Epoch: 7, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29
# Epoch: 7, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29
# Epoch: 7, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29
# model accuracy: 0.96
# model accuracy: 0.929
# model accuracy: 0.919
# model accuracy: 0.946
# Full accuracy: 0.96, LC accuracy: 0.946, Decomposed-Full accuracy: 0.929, Decomposed-Restored accuracy: 0.919
# Epoch: 7, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29
# Epoch: 7, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29
# Epoch: 7, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29
# Epoch: 7, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_29
# Epoch: 7, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30/base_model.pt
# Training Accuracy | Decomposed: 0.71875, Full : 0.90625
# model accuracy: 0.929
# model accuracy: 0.894
# model accuracy: 0.894
# model accuracy: 0.962
# Full accuracy: 0.929, LC accuracy: 0.962, Decomposed-Full accuracy: 0.894, Decomposed-Restored accuracy: 0.894
# Epoch: 7, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30
# Epoch: 7, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30
# Epoch: 7, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30
# Epoch: 7, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30
# Epoch: 7, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30
# model accuracy: 0.947
# model accuracy: 0.915
# model accuracy: 0.934
# model accuracy: 0.961
# Full accuracy: 0.947, LC accuracy: 0.961, Decomposed-Full accuracy: 0.915, Decomposed-Restored accuracy: 0.934
# Epoch: 7, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30
# Epoch: 7, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30
# Epoch: 7, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30
# Epoch: 7, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_30
# Epoch: 7, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_31/base_model.pt
# model accuracy: 0.952
# model accuracy: 0.932
# model accuracy: 0.936
# model accuracy: 0.949
# Full accuracy: 0.952, LC accuracy: 0.949, Decomposed-Full accuracy: 0.932, Decomposed-Restored accuracy: 0.936
# Epoch: 7, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_31
# Epoch: 8, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_32/base_model.pt
# Training Accuracy | Decomposed: 0.78125, Full : 0.9375
# Epoch: 8, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_32
# Epoch: 8, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_32
# Epoch: 8, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_32
# Epoch: 8, Iteration: 4
# ...
# model accuracy: 0.943
# model accuracy: 0.978
# Full accuracy: 0.975, LC accuracy: 0.978, Decomposed-Full accuracy: 0.935, Decomposed-Restored accuracy: 0.943
# Epoch: 17, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_69
# Epoch: 17, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_69
# Epoch: 17, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_69
# Epoch: 17, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_69
# Epoch: 17, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_69
# model accuracy: 0.978
# model accuracy: 0.944
# model accuracy: 0.938
# model accuracy: 0.972
# Full accuracy: 0.978, LC accuracy: 0.972, Decomposed-Full accuracy: 0.944, Decomposed-Restored accuracy: 0.938
# Epoch: 17, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_69
# Epoch: 17, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_69
# Epoch: 17, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_69
# Epoch: 17, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_69
# Epoch: 17, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70/base_model.pt
# Training Accuracy | Decomposed: 0.8125, Full : 0.9375
# model accuracy: 0.971
# model accuracy: 0.903
# model accuracy: 0.951
# model accuracy: 0.983
# Full accuracy: 0.971, LC accuracy: 0.983, Decomposed-Full accuracy: 0.903, Decomposed-Restored accuracy: 0.951
# Epoch: 17, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70
# Epoch: 17, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70
# Epoch: 17, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70
# Epoch: 17, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70
# Epoch: 17, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70
# model accuracy: 0.971
# model accuracy: 0.949
# model accuracy: 0.951
# model accuracy: 0.978
# Full accuracy: 0.971, LC accuracy: 0.978, Decomposed-Full accuracy: 0.949, Decomposed-Restored accuracy: 0.951
# Epoch: 17, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70
# Epoch: 17, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70
# Epoch: 17, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70
# Epoch: 17, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_70
# Epoch: 17, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_71/base_model.pt
# model accuracy: 0.983
# model accuracy: 0.949
# model accuracy: 0.947
# model accuracy: 0.981
# Full accuracy: 0.983, LC accuracy: 0.981, Decomposed-Full accuracy: 0.949, Decomposed-Restored accuracy: 0.947
# Epoch: 17, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_71
# Epoch: 18, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72/base_model.pt
# Training Accuracy | Decomposed: 0.9375, Full : 0.96875
# Epoch: 18, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72
# Epoch: 18, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72
# Epoch: 18, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72
# Epoch: 18, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72
# Epoch: 18, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72
# model accuracy: 0.977
# model accuracy: 0.937
# model accuracy: 0.937
# model accuracy: 0.984
# Full accuracy: 0.977, LC accuracy: 0.984, Decomposed-Full accuracy: 0.937, Decomposed-Restored accuracy: 0.937
# Epoch: 18, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72
# Epoch: 18, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72
# Epoch: 18, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72
# Epoch: 18, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_72
# Epoch: 18, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73/base_model.pt
# model accuracy: 0.978
# model accuracy: 0.926
# model accuracy: 0.936
# model accuracy: 0.982
# Full accuracy: 0.978, LC accuracy: 0.982, Decomposed-Full accuracy: 0.926, Decomposed-Restored accuracy: 0.936
# Epoch: 18, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73
# Epoch: 18, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73
# Epoch: 18, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73
# Epoch: 18, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73
# Epoch: 18, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73
# model accuracy: 0.982
# model accuracy: 0.952
# model accuracy: 0.936
# model accuracy: 0.978
# Full accuracy: 0.982, LC accuracy: 0.978, Decomposed-Full accuracy: 0.952, Decomposed-Restored accuracy: 0.936
# Epoch: 18, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73
# Epoch: 18, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73
# Epoch: 18, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73
# Epoch: 18, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_73
# Epoch: 18, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74/base_model.pt
# Training Accuracy | Decomposed: 0.875, Full : 0.90625
# model accuracy: 0.969
# model accuracy: 0.941
# model accuracy: 0.941
# model accuracy: 0.985
# Full accuracy: 0.969, LC accuracy: 0.985, Decomposed-Full accuracy: 0.941, Decomposed-Restored accuracy: 0.941
# Epoch: 18, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74
# Epoch: 18, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74
# Epoch: 18, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74
# Epoch: 18, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74
# Epoch: 18, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74
# model accuracy: 0.981
# model accuracy: 0.933
# model accuracy: 0.948
# model accuracy: 0.981
# Full accuracy: 0.981, LC accuracy: 0.981, Decomposed-Full accuracy: 0.933, Decomposed-Restored accuracy: 0.948
# Epoch: 18, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74
# Epoch: 18, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74
# Epoch: 18, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74
# Epoch: 18, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_74
# Epoch: 18, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_75/base_model.pt
# model accuracy: 0.986
# model accuracy: 0.946
# model accuracy: 0.95
# model accuracy: 0.985
# Full accuracy: 0.986, LC accuracy: 0.985, Decomposed-Full accuracy: 0.946, Decomposed-Restored accuracy: 0.95
# Epoch: 18, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_75
# Epoch: 19, Iteration: 0
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76/base_model.pt
# Training Accuracy | Decomposed: 1.0, Full : 0.90625
# Epoch: 19, Iteration: 1
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76
# Epoch: 19, Iteration: 2
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76
# Epoch: 19, Iteration: 3
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76
# Epoch: 19, Iteration: 4
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76
# Epoch: 19, Iteration: 5
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76
# model accuracy: 0.978
# model accuracy: 0.944
# model accuracy: 0.95
# model accuracy: 0.972
# Full accuracy: 0.978, LC accuracy: 0.972, Decomposed-Full accuracy: 0.944, Decomposed-Restored accuracy: 0.95
# Epoch: 19, Iteration: 6
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76
# Epoch: 19, Iteration: 7
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76
# Epoch: 19, Iteration: 8
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76
# Epoch: 19, Iteration: 9
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_76
# Epoch: 19, Iteration: 10
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77/base_model.pt
# model accuracy: 0.971
# model accuracy: 0.927
# model accuracy: 0.942
# model accuracy: 0.979
# Full accuracy: 0.971, LC accuracy: 0.979, Decomposed-Full accuracy: 0.927, Decomposed-Restored accuracy: 0.942
# Epoch: 19, Iteration: 11
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77
# Epoch: 19, Iteration: 12
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77
# Epoch: 19, Iteration: 13
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77
# Epoch: 19, Iteration: 14
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77
# Epoch: 19, Iteration: 15
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77
# model accuracy: 0.981
# model accuracy: 0.942
# model accuracy: 0.937
# model accuracy: 0.98
# Full accuracy: 0.981, LC accuracy: 0.98, Decomposed-Full accuracy: 0.942, Decomposed-Restored accuracy: 0.937
# Epoch: 19, Iteration: 16
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77
# Epoch: 19, Iteration: 17
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77
# Epoch: 19, Iteration: 18
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77
# Epoch: 19, Iteration: 19
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_77
# Epoch: 19, Iteration: 20
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78/base_model.pt
# Training Accuracy | Decomposed: 0.90625, Full : 0.90625
# model accuracy: 0.97
# model accuracy: 0.912
# model accuracy: 0.948
# model accuracy: 0.979
# Full accuracy: 0.97, LC accuracy: 0.979, Decomposed-Full accuracy: 0.912, Decomposed-Restored accuracy: 0.948
# Epoch: 19, Iteration: 21
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78
# Epoch: 19, Iteration: 22
# Saving Checkpoint lc_checkpoint_1.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78
# Epoch: 19, Iteration: 23
# Saving Checkpoint lc_checkpoint_2.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78
# Epoch: 19, Iteration: 24
# Saving Checkpoint lc_checkpoint_3.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78
# Epoch: 19, Iteration: 25
# Saving Checkpoint lc_checkpoint_4.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78
# model accuracy: 0.979
# model accuracy: 0.952
# model accuracy: 0.95
# model accuracy: 0.984
# Full accuracy: 0.979, LC accuracy: 0.984, Decomposed-Full accuracy: 0.952, Decomposed-Restored accuracy: 0.95
# Epoch: 19, Iteration: 26
# Saving Checkpoint lc_checkpoint_5.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78
# Epoch: 19, Iteration: 27
# Saving Checkpoint lc_checkpoint_6.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78
# Epoch: 19, Iteration: 28
# Saving Checkpoint lc_checkpoint_7.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78
# Epoch: 19, Iteration: 29
# Saving Checkpoint lc_checkpoint_8.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_78
# Epoch: 19, Iteration: 30
# saving full base model @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_79/base_model.pt
# model accuracy: 0.987
# model accuracy: 0.947
# model accuracy: 0.953
# model accuracy: 0.984
# Full accuracy: 0.987, LC accuracy: 0.984, Decomposed-Full accuracy: 0.947, Decomposed-Restored accuracy: 0.953
# Epoch: 19, Iteration: 31
# Saving Checkpoint lc_checkpoint_0.pt @ /volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/lobranch/set_79

# %%
import json

with open(HDFP + "/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet-data.json") as f:
    data = json.load(f)
full_accuracy = data['full_acc']
lc_accuracy = data["lc_restored_accuracy"]
restored_accuracy = data["decomposed_restored_accuracy"]
decomposed_full_accuracy = data["decomposed_full_accuracy"]

# %%
plt.figure(figsize = (30, 5))
plt.title("AlexNet, Accuracy, Branched @ {} Accuracy".format(BRANCH_ACC))
plt.plot(full_accuracy, label = "Default AlexNet")
plt.plot(lc_accuracy, label = "LC AlexNet")
plt.plot(decomposed_full_accuracy, label = "dLoRA AlexNet")
plt.plot(restored_accuracy, label = "dLoRA + LC AlexNet")
plt.xticks([x for x in range(0, 120) if x % 6 == 0], [x for x in range(0, 20)])
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
rangex = [x for x in np.arange(0, 1, 200) if x % 10 == 0]
rangey = [x for x in np.arange(0, 1, 20)]
plt.figure(figsize = (40, 10))
ax1 = plt.subplot(1, 2, 1)
ax1.set_title("AlexNet Absolute Accuracy Loss (Default AlexNet vs LC AlexNet / LC + dLoRA AlexNet)".format(RANK))
plt.plot(np.abs(np.subtract(np.array(full_accuracy), 
                     np.array(restored_accuracy))), label = "LC + dLoRA AlexNet")
plt.plot(np.abs(np.subtract(np.array(full_accuracy), 
                     np.array(lc_accuracy))), label = "LC AlexNet")
plt.legend()
plt.xticks(rangex, rangey)
plt.ylabel("Absolute Accuracy Loss")
plt.xlabel("Epoch")
plt.axhline(y = 0.05, color = 'r')
plt.ylim(0, 0.5)
ax2 = plt.subplot(1, 2, 2)
ax2.set_title("AlexNet Absolute Restoration Accuracy Loss (LC + dLoRA AlexNet & LC AlexNet)")
plt.plot(np.abs(np.subtract(np.array(restored_accuracy), 
                     np.array(decomposed_full_accuracy))), label = "LC + dLoRA AlexNet")
plt.plot(np.abs(np.subtract(np.array(full_accuracy), 
                     np.array(lc_accuracy))), label = "LC AlexNet")
plt.legend()
plt.axhline(y = 0.05, color = 'r')
plt.ylim(0, 0.5)
plt.xticks(rangex, rangey)
plt.ylabel("Absolute Accuracy Loss")
plt.xlabel("Epoch")
plt.show()

# %%
import math
def getsize(sl):
    dir = [x for x in os.listdir(sl)]
    csize, usize = 0, 0
    for set in dir:
        for f in os.listdir(sl + "/" + set):
            fp = sl + "/{}/{}".format(set, f)
            csize += os.path.getsize(fp)
            usize += 46.8 * math.pow(2, 20)
    return csize, usize,

def getsize_og_lc(sl):
    dir = [x for x in os.listdir(sl)]
    csize, usize = 0, 0
    for set in dir:
        for f in os.listdir(sl + "/" + set):
            fp = sl + "/{}/{}".format(set, f)
            csize += 1.2 * math.pow(2, 20)
            usize += 46.8 * math.pow(2, 20)
        csize += 46.8 * math.pow(2, 20)
    return csize, usize,

# %%
compressed_size, uncompressed_size = getsize(SAVE_LOC)
a, b = evaluate_compression(uncompressed_size, compressed_size)
compressed_size, uncompressed_size = getsize(SAVE_LOC_OLC)
a1, b1 = evaluate_compression(uncompressed_size, compressed_size)
compressed_size, uncompressed_size = getsize_og_lc(SAVE_LOC_OLC)
a2, b2 = evaluate_compression(uncompressed_size, compressed_size)

print("LC-Checkpoint + GZIP")
print("Compression Ratio: {}%, Space Savings: {}%".format(a1, b1))
print("LoRA + LC-Checkpoint + GZIP")
print("Compression Ratio: {}%, Space Savings: {}%".format(a, b))
print("LC-Checkpoint")
print("Compression Ratio: {}%, Space Savings: {}%".format(a2, b2))
# Out:
# LC-Checkpoint + GZIP
# Compression Ratio: 805.855%, Space Savings: 87.591%
# LoRA + LC-Checkpoint + GZIP
# Compression Ratio: 26009.831000000002%, Space Savings: 99.616%
# LC-Checkpoint
# Compression Ratio: 663.83%, Space Savings: 84.936%

# %%
import json
data = {
    "full_acc" : full_accuracy,
    "decomposed_restored_accuracy" : restored_accuracy,
    "decomposed_full_accuracy" : decomposed_full_accuracy,
    "lc_restored_accuracy" : lc_accuracy
}
with open(HDFP + "/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet-data.json", 'w') as f:
    json.dump(data, f)
