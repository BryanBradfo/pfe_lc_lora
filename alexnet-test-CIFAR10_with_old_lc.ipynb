# %% [markdown]
# # AlexNet Implementation with Old_LC on CIFAR-10

# %%
import glob
import sys
import os
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import scipy as spy
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
from torch.utils.data.sampler import SubsetRandomSampler
import ssl
import pickle, json
import src.main as lc
import old_lc.main as olc
from src.models.AlexNet_CIFAR10 import AlexNet_CIFAR10
from src.models.AlexNet import AlexNet
import torchvision
import src.compression.deltaCompress as lc_compress
from src.models.AlexNet_CIFAR10LowRank import getBase, AlexNet_CIFAR10LowRank, load_sd_decomp
from src.models.AlexNet_LowRank import getBase, AlexNet_LowRank, load_sd_decomp
from src.utils.utils import evaluate_accuracy, lazy_restore, evaluate_compression
# Out:
# c:\Users\Bradf\anaconda3\envs\py310\lib\site-packages\transformers\utils\generic.py:485: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %% [markdown]
# ## Definition of Data Loader function

# %%
HDFP = "./volumes/Ultra Touch" # Load HHD
def data_loader():
    # transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    trainset = datasets.CIFAR10(root='./data_CIFAR10', download=True, train=True, transform=transform)

    # trainset = datasets.MNIST(root='./data', train=True,
                                        #   download=True, transform=transform)
    # Reintroduce the 2000 datapoints model has not seen before.
    trainset.data = trainset.data[-2000:-1000]
    trainset.targets = trainset.targets[-2000:-1000]
    # trainset.data = trainset.data[-56000:]
    # trainset.targets = trainset.targets[-56000:]
    trainloader = torch.utils.data.DataLoader(trainset, batch_size = 32,
                                              shuffle=False, num_workers=2)

    testset = datasets.CIFAR10('./data_CIFAR10', download=True, train=False, transform=transform)

    # testset = datasets.MNIST(root='./data', train=False,
    #                                      download=True, transform=transform)

    testset.data = trainset.data[-1000:]
    testset.targets = trainset.targets[-1000:]
    # testset.data = trainset.data[:1000]
    # testset.targets = trainset.targets[:1000]
    testloader = torch.utils.data.DataLoader(testset, batch_size = 32,
                                             shuffle=False, num_workers=2)
    
    return trainloader, testloader


# HDFP = "./volumes/Ultra Touch"  # Placeholder for HDD path

# def data_loader():
#     transform = transforms.Compose([
#         transforms.ToTensor(),
#         transforms.Normalize((0.1307,), (0.3081,))
#     ])

#     # Load the MNIST training dataset
#     trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
#     # Use the last 10,000 images for training
#     trainset.data = trainset.data.clone()[-56000:]
#     trainset.targets = trainset.targets.clone()[-56000:]
#     # trainset.data = trainset.data.clone()[-58000:]
#     # trainset.targets = trainset.targets.clone()[-58000:]
#     train_loader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=2)

#     # Load the MNIST test dataset
#     testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
#     # Use the first 1,000 images from the test dataset
#     testset.data = testset.data.clone()[:1000]
#     testset.targets = testset.targets.clone()[:1000]
#     test_loader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False, num_workers=2)
    
#     return train_loader, test_loader

# %% [markdown]
# ## Calling CIFAR-10 dataset

# %%
# Bypass using SSL unverified
ssl._create_default_https_context = ssl._create_unverified_context
# MNIST dataset 
train_loader, test_loader = data_loader()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Bypass the matplotlib error

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ## Showing some images of the dataset we use

# %%
    # # Adjust these values to match the normalization values used during the loading of your dataset
    # mean = 0.5
    # std = 0.5

    # # Function to show an image
    # def imshow(img):
    #     # Adjusting unnormalization for potentially 3-channel images
    #     img = img * std + mean  # Unnormalize
    #     npimg = img.numpy()
    #     plt.imshow(np.transpose(npimg, (1, 2, 0)))
    #     plt.show()

    # # Assuming train_loader is defined and loaded as before
    # dataiter = iter(train_loader)
    # images, labels = next(dataiter)

    # # Show images
    # imshow(torchvision.utils.make_grid(images[:3]))
    # # Print labels
    # print(' '.join('%5s' % labels[j] for j in range(3)))

    # Mapping des labels aux noms de classe
    classes = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

    # Affichage des images avec les noms de classe
    def imshow(img):
        img = img / 2 + 0.5  # Unnormalize
        npimg = img.numpy()
        plt.figure(figsize=(4, 4))
        plt.imshow(np.transpose(npimg, (1, 2, 0)), interpolation='nearest')
        plt.show()

    # Chargement des données
    dataiter = iter(train_loader)
    images, labels = next(dataiter)

    # Affichage des images
    imshow(torchvision.utils.make_grid(images[:3]))

    # Impression des noms de classe
    print(' | '.join('%5s' % classes[labels[j]] for j in range(3)))
# Out:
# automobile | airplane |  bird

# %% [markdown]
# ## Creation of folder to save the results (for plots and compression rate)

# %%
SAVE_LOC = HDFP + "/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch"
if not os.path.exists(SAVE_LOC):
    os.makedirs(SAVE_LOC)

SAVE_LOC_OLC = HDFP + "/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc"
if not os.path.exists(SAVE_LOC_OLC):
    os.makedirs(SAVE_LOC_OLC)

# %% [markdown]
# ## Definition of the accuracy functions

# %%
def accuracy_binary(model, evaluation_set):
    model.eval()  # Switches the model to evaluation mode.

    no_correct, no_seen = 0, 0  # Initialize counters for correct predictions and total samples seen.

    with torch.no_grad():  # Disables gradient calculation.
        for input, label in evaluation_set:  # Iterate over the evaluation dataset.
            output = torch.sigmoid(model(input))  # Apply sigmoid to model output to get probabilities.
            output = torch.where(output > 0.5, 1, 0)  # Threshold probabilities at 0.5 to decide between classes 0 and 1.
            no_seen += label.size(0)  # Count the number of samples seen (batch size).
            no_correct += (output == label).sum().item()  # Increment correct predictions by the number of matches in the batch.
    
    acc = no_correct / no_seen  # Calculate accuracy as the ratio of correct predictions to total samples.
    model.train()  # Switch the model back to training mode.
    return acc  # Return the computed accuracy.

def accuracy_multiclass(model, evaluation_set):
    model.eval()  # Switches the model to evaluation mode.

    no_correct, no_seen = 0, 0  # Initialize counters for correct predictions and total samples seen.

    with torch.no_grad():  # Disables gradient calculation.
        for input, label in evaluation_set:  # Iterate over the evaluation dataset.
            output = model(input)  # Get the raw logits from the model.
            pred = output.argmax(dim=1, keepdim=True)  # Get the index of the max logit which represents the predicted class.
            no_seen += label.size(0)  # Count the number of samples seen (batch size).
            no_correct += pred.eq(label.view_as(pred)).sum().item()  # Compare predictions with true labels and sum up correct predictions.
    
    acc = no_correct / no_seen  # Calculate accuracy as the ratio of correct predictions to total samples.
    model.train()  # Switch the model back to training mode.
    return acc  # Return the computed accuracy.

# %% [markdown]
# ## Usual training on CPU (Creating branchpoints)

# %%
# get the base model (AlexNet)

model_for_checkpoint = AlexNet_CIFAR10()

# creating branchpoints : 

epochs = 10
isLoop = True
optimizer = torch.optim.SGD(model_for_checkpoint.parameters(), lr=0.01, momentum=0.9) # momentum=0.9

for epoch in range(epochs):
    for iter, data in enumerate(train_loader):
        inputs, labels = data
        # print(inputs, labels)
        optimizer.zero_grad()
        outputs = model_for_checkpoint(inputs)

        # if self.config.loss_function == "binary_cross_entropy":
        #     outputs = torch.sigmoid(outputs)
        
        # loss = loss_function(outputs, labels)
        loss = torch.nn.CrossEntropyLoss()(outputs, labels)
        loss.backward()
        optimizer.step()

        # print("Epoch {} | Iteration {} : Loss {}".format(epoch, iter, loss.item()))
        if iter % 20 == 0:
            print("Running validation for {} Epoch, {} Iteration...".format(epoch, iter))
            # Previously: res = accuracy_binary(model_for_checkpoint, test_loader)
            res = accuracy_multiclass(model_for_checkpoint, test_loader)

            # res = accuracy_binary(model_for_checkpoint, test_loader)
            
            print("ACCURACY: {}".format(res))
            if res > 0.7:
                torch.save(model_for_checkpoint.state_dict(), HDFP + "/lobranch-snapshot/branchpoints/alexnet/branch_{}.pt".format(res))
            if res > 0.9:
                isLoop = False
                break
    if not isLoop:
        break
    print("Length of train_loader is: ", len(train_loader))

# %% [markdown]
# ## Exploiting branchpoints of the model

# %% [markdown]
# ### Call of the different models to compare

# %%
DECOMPOSED_LAYERS = ["classifier.1.weight", "classifier.4.weight"]
RANK = -1
SCALING = -1
BRANCH_ACC = "0.8"

# Set up weights for original AlexNet model
original = AlexNet_CIFAR10()
model_original = AlexNet_CIFAR10()

# Load from "branch point"
BRANCH_LOC = HDFP + "/lobranch-snapshot/branchpoints/alexnet/branch_{}.pt".format(BRANCH_ACC)
original.load_state_dict(torch.load(BRANCH_LOC))
model_original.load_state_dict(torch.load(BRANCH_LOC))

w, b = getBase(model_original)
model = AlexNet_CIFAR10LowRank(w, b, rank = RANK)
load_sd_decomp(torch.load(BRANCH_LOC), model, DECOMPOSED_LAYERS)
learning_rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)
optimizer_full = torch.optim.SGD(model_original.parameters(), lr = learning_rate)

# %% [markdown]
# ### Training using checkpoint, creation of model with only LC-checkpoint and another with LC-checkpoint + LoRA

# %%
delta_normal_max = []
delta_normal_min = []
delta_decomposed_max = []
delta_decomposed_min = []
full_accuracy = []
decomposed_full_accuracy = []
restored_accuracy = []
lc_accuracy = []
current_iter = 0
current_set = 0

current_iter_old_lc = 0
current_set_old_lc = 0

acc = lambda x, y : (torch.max(x, 1)[1] == y).sum().item() / y.size(0)

for epch in range(20):
    for i, data in enumerate(train_loader, 0):
        print("Epoch: {}, Iteration: {}".format(epch, i))
        
        set_path = "/set_{}".format(current_set)
        if not os.path.exists(SAVE_LOC + set_path):
            os.makedirs(SAVE_LOC + set_path)

        if i == 0 and epch == 0: # first iteration, create baseline model
            base, base_decomp = lc.extract_weights(model, SAVE_LOC + 
                                                       "/set_{}".format(current_set), DECOMPOSED_LAYERS)
        else:
            if i % 10 == 0: 
                # full snapshot!
                new_model = lazy_restore(base, base_decomp, bias, AlexNet_CIFAR10(), 
                                          original.state_dict(), DECOMPOSED_LAYERS, rank = RANK, scaling = SCALING)
                
                original = new_model # Changing previous "original model" used to restore the loRA model.
                
                current_set += 1
                current_iter = 0

                set_path = "/set_{}".format(current_set)
                if not os.path.exists(SAVE_LOC + set_path):
                    os.makedirs(SAVE_LOC + set_path)
                
                # Rebuilding LoRA layers => reset model!
                w, b = getBase(original)
                model = AlexNet_CIFAR10LowRank(w, b, rank = RANK)
                optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)
                load_sd_decomp(original.state_dict(), model, DECOMPOSED_LAYERS)
                base, base_decomp = lc.extract_weights(model, SAVE_LOC + 
                                                       "/set_{}".format(current_set), DECOMPOSED_LAYERS)

            else:
                # Delta-compression 
                delta, decomp_delta, bias = lc.generate_delta(base, 
                                                                base_decomp, model.state_dict(), DECOMPOSED_LAYERS)
                compressed_delta, full_delta, compressed_dcomp_delta, full_dcomp_delta  = lc.compress_delta(delta, 
                                                                                                            decomp_delta)
                
                # Saving checkpoint
                lc.save_checkpoint(compressed_delta, compressed_dcomp_delta, bias, current_iter, SAVE_LOC + 
                                "/set_{}".format(current_set))
    
                base = np.add(base, full_delta) # Replace base with latest for delta to accumulate.
                base_decomp = np.add(full_dcomp_delta, base_decomp)

                current_iter += 1
            
        # ==========================
        # Saving using LC-Checkpoint
        # ==========================
        
        if i == 0 and epch == 0:
            cstate = model_original.state_dict()
            set_path = "/set_{}".format(current_set_old_lc)
            if not os.path.exists(SAVE_LOC_OLC + set_path):
                os.makedirs(SAVE_LOC_OLC + set_path)
            # torch.save(cstate, SAVE_LOC_OLC + set_path + "/initial_model.pt")
            # prev_state = olc.extract_weights(model_original)
            prev_state = olc.extract_weights(cstate, SAVE_LOC_OLC + set_path, DECOMPOSED_LAYERS)
        else:
            if i % 10 == 0:
                cstate = model_original.state_dict()
                current_set_old_lc += 1
                current_iter_old_lc = 0
                set_path = "/set_{}".format(current_set_old_lc)
                if not os.path.exists(SAVE_LOC_OLC + set_path):
                    os.makedirs(SAVE_LOC_OLC + set_path)
                # torch.save(cstate, SAVE_LOC_OLC + set_path + "/initial_model.pt")
                # prev_state = olc.extract_weights(model_original)
                prev_state = olc.extract_weights(cstate, SAVE_LOC_OLC + set_path, DECOMPOSED_LAYERS)
            else:
                cstate = model_original.state_dict()
                old_lc_delta, old_lc_bias = olc.generate_delta(prev_state, cstate, DECOMPOSED_LAYERS)
                olc_compressed_delta, update_prev = olc.compress_data(old_lc_delta)
                olc.save_checkpoint(SAVE_LOC_OLC + "/set_{}".format(current_set_old_lc), olc_compressed_delta, 
                                    old_lc_bias, current_iter_old_lc)
                prev_state = np.add(prev_state, update_prev)
                current_iter_old_lc += 1

        # if i == 0 and epch == 0:
        #     cstate = model_original.state_dict()
        #     set_path = "/set_{}".format(current_set_old_lc)
        #     if not os.path.exists(SAVE_LOC_OLC + set_path):
        #         os.makedirs(SAVE_LOC_OLC + set_path)
        #     torch.save(cstate, SAVE_LOC_OLC + set_path + "/initial_model.pt")
        #     # prev_state = olc.extract_weights(model_original)
        #     prev_state = olc.extract_weights(cstate)
        # else:
        #     if i % 10 == 0:
        #         cstate = model_original.state_dict()
        #         current_set_old_lc += 1
        #         current_iter_old_lc = 0
        #         set_path = "/set_{}".format(current_set_old_lc)
        #         if not os.path.exists(SAVE_LOC_OLC + set_path):
        #             os.makedirs(SAVE_LOC_OLC + set_path)
        #         torch.save(cstate, SAVE_LOC_OLC + set_path + "/initial_model.pt")
        #         # prev_state = olc.extract_weights(model_original)
        #         prev_state = olc.extract_weights(cstate)
        #     else:
        #         cstate = model_original.state_dict()
        #         old_lc_delta, old_lc_bias = olc.generate_delta(prev_state, cstate)
        #         olc_compressed_delta, update_prev = olc.compress_data(old_lc_delta, num_bits = 3)
        #         olc.save_checkpoint(SAVE_LOC_OLC + "/set_{}".format(current_set_old_lc), olc_compressed_delta, 
        #                             old_lc_bias, epch, current_iter_old_lc)
        #         prev_state = np.add(prev_state, update_prev)
        #         current_iter_old_lc += 1
        
        # ==========================
        # Training on Low-Rank Model
        # ==========================

        # Get the inputs and labels
        inputs, labels = data

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward + backward + optimize
        outputs = model(inputs)
        loss = torch.nn.functional.cross_entropy(outputs,labels)
        loss.backward()
        optimizer.step()
            
        # ======================
        # Training on Full Model
        # ======================

        # Zero the parameter gradients
        optimizer_full.zero_grad()

        # Forward + backward + optimize
        outputs_full = model_original(inputs)
        loss_full = torch.nn.functional.cross_entropy(outputs_full,labels)
        loss_full.backward()
        optimizer_full.step()

        if i % 20 == 0:
            print("Training Accuracy | Decomposed: {}, Full : {}".format(acc(outputs, labels), 
                                                                         acc(outputs_full, labels)))

        if i != 0  and i % 5 == 0: # Evaluation on testing set
            full_accuracy.append(evaluate_accuracy(model_original, test_loader))
            decomposed_full_accuracy.append(evaluate_accuracy(model, test_loader))
            restored_model = lazy_restore(base, base_decomp, bias, AlexNet_CIFAR10(), 
                                          original.state_dict(), DECOMPOSED_LAYERS, 
                                          rank = RANK, scaling = SCALING)
            restored_accuracy.append(evaluate_accuracy(restored_model, test_loader))
            restored_lc_model = AlexNet_CIFAR10()
            restored_lc_model.load_state_dict(olc.restore_state_dict(prev_state, old_lc_bias, 
                                                                  restored_model.state_dict(), DECOMPOSED_LAYERS))
            lc_accuracy.append(evaluate_accuracy(restored_lc_model, test_loader))
            print("Full accuracy: {}, LC accuracy: {}, Decomposed-Full accuracy: {}, Decomposed-Restored accuracy: {}".format(
                full_accuracy[-1], lc_accuracy[-1], decomposed_full_accuracy[-1], restored_accuracy[-1]))
# Out:
# Epoch: 0, Iteration: 0
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0/initial_model.pt
# Training Accuracy | Decomposed: 0.6875, Full : 0.75
# Epoch: 0, Iteration: 1
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0
# Epoch: 0, Iteration: 2
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0
# Epoch: 0, Iteration: 3
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0
# Epoch: 0, Iteration: 4
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0
# Epoch: 0, Iteration: 5
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0
# model accuracy: 0.838
# model accuracy: 0.831
# model accuracy: 0.827
# model accuracy: 0.833
# Full accuracy: 0.838, LC accuracy: 0.833, Decomposed-Full accuracy: 0.831, Decomposed-Restored accuracy: 0.827
# Epoch: 0, Iteration: 6
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0
# Epoch: 0, Iteration: 7
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0
# Epoch: 0, Iteration: 8
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0
# Epoch: 0, Iteration: 9
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_0
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_0
# Epoch: 0, Iteration: 10
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1/initial_model.pt
# model accuracy: 0.846
# model accuracy: 0.837
# model accuracy: 0.833
# model accuracy: 0.843
# Full accuracy: 0.846, LC accuracy: 0.843, Decomposed-Full accuracy: 0.837, Decomposed-Restored accuracy: 0.833
# Epoch: 0, Iteration: 11
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1
# Epoch: 0, Iteration: 12
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1
# Epoch: 0, Iteration: 13
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1
# Epoch: 0, Iteration: 14
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1
# Epoch: 0, Iteration: 15
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1
# model accuracy: 0.853
# model accuracy: 0.843
# model accuracy: 0.844
# model accuracy: 0.855
# Full accuracy: 0.853, LC accuracy: 0.855, Decomposed-Full accuracy: 0.843, Decomposed-Restored accuracy: 0.844
# Epoch: 0, Iteration: 16
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1
# Epoch: 0, Iteration: 17
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1
# Epoch: 0, Iteration: 18
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1
# Epoch: 0, Iteration: 19
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_1
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_1
# Epoch: 0, Iteration: 20
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2/initial_model.pt
# Training Accuracy | Decomposed: 0.9375, Full : 0.875
# model accuracy: 0.861
# model accuracy: 0.842
# model accuracy: 0.842
# model accuracy: 0.862
# Full accuracy: 0.861, LC accuracy: 0.862, Decomposed-Full accuracy: 0.842, Decomposed-Restored accuracy: 0.842
# Epoch: 0, Iteration: 21
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2
# Epoch: 0, Iteration: 22
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2
# Epoch: 0, Iteration: 23
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2
# Epoch: 0, Iteration: 24
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2
# Epoch: 0, Iteration: 25
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2
# model accuracy: 0.864
# model accuracy: 0.852
# model accuracy: 0.853
# model accuracy: 0.863
# Full accuracy: 0.864, LC accuracy: 0.863, Decomposed-Full accuracy: 0.852, Decomposed-Restored accuracy: 0.853
# Epoch: 0, Iteration: 26
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2
# Epoch: 0, Iteration: 27
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2
# Epoch: 0, Iteration: 28
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2
# Epoch: 0, Iteration: 29
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_2
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_2
# Epoch: 0, Iteration: 30
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_3\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_3/initial_model.pt
# model accuracy: 0.865
# model accuracy: 0.855
# model accuracy: 0.853
# model accuracy: 0.867
# Full accuracy: 0.865, LC accuracy: 0.867, Decomposed-Full accuracy: 0.855, Decomposed-Restored accuracy: 0.853
# Epoch: 0, Iteration: 31
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_3
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_3
# Epoch: 1, Iteration: 0
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4/initial_model.pt
# Training Accuracy | Decomposed: 0.75, Full : 0.75
# Epoch: 1, Iteration: 1
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4
# Epoch: 1, Iteration: 2
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4
# Epoch: 1, Iteration: 3
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4
# Epoch: 1, Iteration: 4
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4
# Epoch: 1, Iteration: 5
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4
# model accuracy: 0.869
# model accuracy: 0.86
# model accuracy: 0.858
# model accuracy: 0.867
# Full accuracy: 0.869, LC accuracy: 0.867, Decomposed-Full accuracy: 0.86, Decomposed-Restored accuracy: 0.858
# Epoch: 1, Iteration: 6
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4
# Epoch: 1, Iteration: 7
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4
# Epoch: 1, Iteration: 8
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4
# Epoch: 1, Iteration: 9
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_4
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_4
# Epoch: 1, Iteration: 10
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5/initial_model.pt
# model accuracy: 0.878
# model accuracy: 0.864
# model accuracy: 0.864
# model accuracy: 0.873
# Full accuracy: 0.878, LC accuracy: 0.873, Decomposed-Full accuracy: 0.864, Decomposed-Restored accuracy: 0.864
# Epoch: 1, Iteration: 11
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5
# Epoch: 1, Iteration: 12
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5
# Epoch: 1, Iteration: 13
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5
# Epoch: 1, Iteration: 14
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5
# Epoch: 1, Iteration: 15
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5
# model accuracy: 0.884
# model accuracy: 0.868
# model accuracy: 0.867
# model accuracy: 0.883
# Full accuracy: 0.884, LC accuracy: 0.883, Decomposed-Full accuracy: 0.868, Decomposed-Restored accuracy: 0.867
# Epoch: 1, Iteration: 16
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5
# Epoch: 1, Iteration: 17
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5
# Epoch: 1, Iteration: 18
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5
# Epoch: 1, Iteration: 19
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_5
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_5
# Epoch: 1, Iteration: 20
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6/initial_model.pt
# Training Accuracy | Decomposed: 0.9375, Full : 0.90625
# model accuracy: 0.885
# model accuracy: 0.87
# model accuracy: 0.87
# model accuracy: 0.885
# Full accuracy: 0.885, LC accuracy: 0.885, Decomposed-Full accuracy: 0.87, Decomposed-Restored accuracy: 0.87
# Epoch: 1, Iteration: 21
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6
# Epoch: 1, Iteration: 22
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6
# Epoch: 1, Iteration: 23
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6
# Epoch: 1, Iteration: 24
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6
# Epoch: 1, Iteration: 25
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6
# model accuracy: 0.885
# model accuracy: 0.871
# model accuracy: 0.873
# model accuracy: 0.888
# Full accuracy: 0.885, LC accuracy: 0.888, Decomposed-Full accuracy: 0.871, Decomposed-Restored accuracy: 0.873
# Epoch: 1, Iteration: 26
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6
# Epoch: 1, Iteration: 27
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6
# Epoch: 1, Iteration: 28
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6
# Epoch: 1, Iteration: 29
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_6
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_6
# Epoch: 1, Iteration: 30
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_7\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_7/initial_model.pt
# model accuracy: 0.884
# model accuracy: 0.873
# model accuracy: 0.875
# model accuracy: 0.887
# Full accuracy: 0.884, LC accuracy: 0.887, Decomposed-Full accuracy: 0.873, Decomposed-Restored accuracy: 0.875
# Epoch: 1, Iteration: 31
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_7
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_7
# Epoch: 2, Iteration: 0
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8/initial_model.pt
# Training Accuracy | Decomposed: 0.65625, Full : 0.84375
# Epoch: 2, Iteration: 1
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8
# Epoch: 2, Iteration: 2
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8
# Epoch: 2, Iteration: 3
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8
# Epoch: 2, Iteration: 4
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8
# Epoch: 2, Iteration: 5
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8
# model accuracy: 0.891
# model accuracy: 0.874
# model accuracy: 0.876
# model accuracy: 0.888
# Full accuracy: 0.891, LC accuracy: 0.888, Decomposed-Full accuracy: 0.874, Decomposed-Restored accuracy: 0.876
# Epoch: 2, Iteration: 6
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8
# Epoch: 2, Iteration: 7
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8
# Epoch: 2, Iteration: 8
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8
# Epoch: 2, Iteration: 9
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_8
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_8
# Epoch: 2, Iteration: 10
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9/initial_model.pt
# model accuracy: 0.894
# model accuracy: 0.879
# model accuracy: 0.876
# model accuracy: 0.891
# Full accuracy: 0.894, LC accuracy: 0.891, Decomposed-Full accuracy: 0.879, Decomposed-Restored accuracy: 0.876
# Epoch: 2, Iteration: 11
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9
# Epoch: 2, Iteration: 12
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9
# Epoch: 2, Iteration: 13
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9
# Epoch: 2, Iteration: 14
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9
# Epoch: 2, Iteration: 15
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9
# model accuracy: 0.902
# model accuracy: 0.883
# model accuracy: 0.884
# model accuracy: 0.899
# Full accuracy: 0.902, LC accuracy: 0.899, Decomposed-Full accuracy: 0.883, Decomposed-Restored accuracy: 0.884
# Epoch: 2, Iteration: 16
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9
# Epoch: 2, Iteration: 17
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9
# Epoch: 2, Iteration: 18
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9
# Epoch: 2, Iteration: 19
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_9
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_9
# Epoch: 2, Iteration: 20
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10/initial_model.pt
# Training Accuracy | Decomposed: 0.90625, Full : 0.90625
# model accuracy: 0.899
# model accuracy: 0.882
# model accuracy: 0.882
# model accuracy: 0.901
# Full accuracy: 0.899, LC accuracy: 0.901, Decomposed-Full accuracy: 0.882, Decomposed-Restored accuracy: 0.882
# Epoch: 2, Iteration: 21
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10
# Epoch: 2, Iteration: 22
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10
# Epoch: 2, Iteration: 23
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10
# Epoch: 2, Iteration: 24
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10
# Epoch: 2, Iteration: 25
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10
# model accuracy: 0.903
# model accuracy: 0.873
# model accuracy: 0.873
# model accuracy: 0.899
# Full accuracy: 0.903, LC accuracy: 0.899, Decomposed-Full accuracy: 0.873, Decomposed-Restored accuracy: 0.873
# Epoch: 2, Iteration: 26
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10
# Epoch: 2, Iteration: 27
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10
# Epoch: 2, Iteration: 28
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10
# Epoch: 2, Iteration: 29
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_10
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_10
# Epoch: 2, Iteration: 30
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_11\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_11/initial_model.pt
# model accuracy: 0.901
# model accuracy: 0.879
# model accuracy: 0.879
# model accuracy: 0.901
# Full accuracy: 0.901, LC accuracy: 0.901, Decomposed-Full accuracy: 0.879, Decomposed-Restored accuracy: 0.879
# Epoch: 2, Iteration: 31
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_11
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_11
# Epoch: 3, Iteration: 0
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12/initial_model.pt
# Training Accuracy | Decomposed: 0.78125, Full : 0.71875
# Epoch: 3, Iteration: 1
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12
# Epoch: 3, Iteration: 2
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12
# Epoch: 3, Iteration: 3
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12
# Epoch: 3, Iteration: 4
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12
# Epoch: 3, Iteration: 5
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12
# model accuracy: 0.902
# model accuracy: 0.881
# model accuracy: 0.88
# model accuracy: 0.903
# Full accuracy: 0.902, LC accuracy: 0.903, Decomposed-Full accuracy: 0.881, Decomposed-Restored accuracy: 0.88
# Epoch: 3, Iteration: 6
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12
# Epoch: 3, Iteration: 7
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12
# Epoch: 3, Iteration: 8
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12
# Epoch: 3, Iteration: 9
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_12
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_12
# Epoch: 3, Iteration: 10
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13/initial_model.pt
# model accuracy: 0.905
# model accuracy: 0.884
# model accuracy: 0.883
# model accuracy: 0.903
# Full accuracy: 0.905, LC accuracy: 0.903, Decomposed-Full accuracy: 0.884, Decomposed-Restored accuracy: 0.883
# Epoch: 3, Iteration: 11
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13
# Epoch: 3, Iteration: 12
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13
# Epoch: 3, Iteration: 13
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13
# Epoch: 3, Iteration: 14
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13
# Epoch: 3, Iteration: 15
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13
# model accuracy: 0.91
# model accuracy: 0.885
# model accuracy: 0.888
# model accuracy: 0.907
# Full accuracy: 0.91, LC accuracy: 0.907, Decomposed-Full accuracy: 0.885, Decomposed-Restored accuracy: 0.888
# Epoch: 3, Iteration: 16
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13
# Epoch: 3, Iteration: 17
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13
# Epoch: 3, Iteration: 18
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13
# Epoch: 3, Iteration: 19
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_13
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_13
# Epoch: 3, Iteration: 20
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14/initial_model.pt
# Training Accuracy | Decomposed: 0.90625, Full : 0.9375
# model accuracy: 0.911
# model accuracy: 0.887
# model accuracy: 0.886
# model accuracy: 0.911
# Full accuracy: 0.911, LC accuracy: 0.911, Decomposed-Full accuracy: 0.887, Decomposed-Restored accuracy: 0.886
# Epoch: 3, Iteration: 21
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14
# Epoch: 3, Iteration: 22
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14
# Epoch: 3, Iteration: 23
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14
# Epoch: 3, Iteration: 24
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14
# Epoch: 3, Iteration: 25
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14
# model accuracy: 0.912
# model accuracy: 0.884
# model accuracy: 0.887
# model accuracy: 0.913
# Full accuracy: 0.912, LC accuracy: 0.913, Decomposed-Full accuracy: 0.884, Decomposed-Restored accuracy: 0.887
# Epoch: 3, Iteration: 26
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14
# Epoch: 3, Iteration: 27
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14
# Epoch: 3, Iteration: 28
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14
# Epoch: 3, Iteration: 29
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_14
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_14
# Epoch: 3, Iteration: 30
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_15\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_15/initial_model.pt
# model accuracy: 0.916
# model accuracy: 0.883
# model accuracy: 0.885
# model accuracy: 0.914
# Full accuracy: 0.916, LC accuracy: 0.914, Decomposed-Full accuracy: 0.883, Decomposed-Restored accuracy: 0.885
# Epoch: 3, Iteration: 31
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_15
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_15
# Epoch: 4, Iteration: 0
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16/initial_model.pt
# Training Accuracy | Decomposed: 0.8125, Full : 0.875
# Epoch: 4, Iteration: 1
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16
# Epoch: 4, Iteration: 2
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16
# Epoch: 4, Iteration: 3
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16
# Epoch: 4, Iteration: 4
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16
# Epoch: 4, Iteration: 5
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16
# model accuracy: 0.918
# model accuracy: 0.888
# model accuracy: 0.886
# model accuracy: 0.917
# Full accuracy: 0.918, LC accuracy: 0.917, Decomposed-Full accuracy: 0.888, Decomposed-Restored accuracy: 0.886
# Epoch: 4, Iteration: 6
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16
# Epoch: 4, Iteration: 7
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16
# Epoch: 4, Iteration: 8
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16
# Epoch: 4, Iteration: 9
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_16
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_16
# Epoch: 4, Iteration: 10
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_17\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_17/initial_model.pt
# model accuracy: 0.921
# model accuracy: 0.888
# model accuracy: 0.886
# model accuracy: 0.922
# Full accuracy: 0.921, LC accuracy: 0.922, Decomposed-Full accuracy: 0.888, Decomposed-Restored accuracy: 0.886
# Epoch: 4, Iteration: 11
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_17
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_17
# Epoch: 4, Iteration: 12
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_17
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_17
# Epoch: 4, Iteration: 13
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_17
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_17
# Epoch: 4, Iteration: 14
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_17
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_17
# Epoch: 4, Iteration: 15
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_17
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_17
# model accuracy: 0.919
# model accuracy: 0.892
# model accuracy: 0.892
# model accuracy: 0.918
# Full accuracy: 0.919, LC accuracy: 0.918, Decomposed-Full accuracy: 0.892, Decomposed-Restored accuracy: 0.892
# Epoch: 4, Iteration: 16
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_17
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_17
# Epoch: 4, Iteration: 17
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_17
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_17
# Epoch: 4, Iteration: 18
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_17
# ...
# model accuracy: 0.994
# Full accuracy: 0.994, LC accuracy: 0.994, Decomposed-Full accuracy: 0.94, Decomposed-Restored accuracy: 0.941
# Epoch: 18, Iteration: 16
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_73
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_73
# Epoch: 18, Iteration: 17
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_73
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_73
# Epoch: 18, Iteration: 18
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_73
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_73
# Epoch: 18, Iteration: 19
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_73
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_73
# Epoch: 18, Iteration: 20
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74/initial_model.pt
# Training Accuracy | Decomposed: 0.90625, Full : 0.9375
# model accuracy: 0.994
# model accuracy: 0.941
# model accuracy: 0.942
# model accuracy: 0.994
# Full accuracy: 0.994, LC accuracy: 0.994, Decomposed-Full accuracy: 0.941, Decomposed-Restored accuracy: 0.942
# Epoch: 18, Iteration: 21
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74
# Epoch: 18, Iteration: 22
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74
# Epoch: 18, Iteration: 23
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74
# Epoch: 18, Iteration: 24
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74
# Epoch: 18, Iteration: 25
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74
# model accuracy: 0.995
# model accuracy: 0.944
# model accuracy: 0.944
# model accuracy: 0.995
# Full accuracy: 0.995, LC accuracy: 0.995, Decomposed-Full accuracy: 0.944, Decomposed-Restored accuracy: 0.944
# Epoch: 18, Iteration: 26
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74
# Epoch: 18, Iteration: 27
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74
# Epoch: 18, Iteration: 28
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74
# Epoch: 18, Iteration: 29
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_74
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_74
# Epoch: 18, Iteration: 30
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_75\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_75/initial_model.pt
# model accuracy: 0.995
# model accuracy: 0.947
# model accuracy: 0.944
# model accuracy: 0.994
# Full accuracy: 0.995, LC accuracy: 0.994, Decomposed-Full accuracy: 0.947, Decomposed-Restored accuracy: 0.944
# Epoch: 18, Iteration: 31
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_75
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_75
# Epoch: 19, Iteration: 0
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76/initial_model.pt
# Training Accuracy | Decomposed: 0.84375, Full : 0.90625
# Epoch: 19, Iteration: 1
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76
# Epoch: 19, Iteration: 2
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76
# Epoch: 19, Iteration: 3
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76
# Epoch: 19, Iteration: 4
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76
# Epoch: 19, Iteration: 5
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76
# model accuracy: 0.997
# model accuracy: 0.941
# model accuracy: 0.941
# model accuracy: 0.996
# Full accuracy: 0.997, LC accuracy: 0.996, Decomposed-Full accuracy: 0.941, Decomposed-Restored accuracy: 0.941
# Epoch: 19, Iteration: 6
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76
# Epoch: 19, Iteration: 7
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76
# Epoch: 19, Iteration: 8
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76
# Epoch: 19, Iteration: 9
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_76
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_76
# Epoch: 19, Iteration: 10
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77/initial_model.pt
# model accuracy: 0.996
# model accuracy: 0.944
# model accuracy: 0.942
# model accuracy: 0.996
# Full accuracy: 0.996, LC accuracy: 0.996, Decomposed-Full accuracy: 0.944, Decomposed-Restored accuracy: 0.942
# Epoch: 19, Iteration: 11
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77
# Epoch: 19, Iteration: 12
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77
# Epoch: 19, Iteration: 13
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77
# Epoch: 19, Iteration: 14
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77
# Epoch: 19, Iteration: 15
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77
# model accuracy: 0.995
# model accuracy: 0.943
# model accuracy: 0.942
# model accuracy: 0.996
# Full accuracy: 0.995, LC accuracy: 0.996, Decomposed-Full accuracy: 0.943, Decomposed-Restored accuracy: 0.942
# Epoch: 19, Iteration: 16
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77
# Epoch: 19, Iteration: 17
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77
# Epoch: 19, Iteration: 18
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77
# Epoch: 19, Iteration: 19
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_77
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_77
# Epoch: 19, Iteration: 20
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78/initial_model.pt
# Training Accuracy | Decomposed: 0.90625, Full : 1.0
# model accuracy: 0.995
# model accuracy: 0.943
# model accuracy: 0.942
# model accuracy: 0.995
# Full accuracy: 0.995, LC accuracy: 0.995, Decomposed-Full accuracy: 0.943, Decomposed-Restored accuracy: 0.942
# Epoch: 19, Iteration: 21
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78
# Epoch: 19, Iteration: 22
# Saving Checkpoint: lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78
# Saving Checkpoint: old_lc_checkpoint_1.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78
# Epoch: 19, Iteration: 23
# Saving Checkpoint: lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78
# Saving Checkpoint: old_lc_checkpoint_2.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78
# Epoch: 19, Iteration: 24
# Saving Checkpoint: lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78
# Saving Checkpoint: old_lc_checkpoint_3.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78
# Epoch: 19, Iteration: 25
# Saving Checkpoint: lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78
# Saving Checkpoint: old_lc_checkpoint_4.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78
# model accuracy: 0.997
# model accuracy: 0.944
# model accuracy: 0.945
# model accuracy: 0.996
# Full accuracy: 0.997, LC accuracy: 0.996, Decomposed-Full accuracy: 0.944, Decomposed-Restored accuracy: 0.945
# Epoch: 19, Iteration: 26
# Saving Checkpoint: lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78
# Saving Checkpoint: old_lc_checkpoint_5.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78
# Epoch: 19, Iteration: 27
# Saving Checkpoint: lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78
# Saving Checkpoint: old_lc_checkpoint_6.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78
# Epoch: 19, Iteration: 28
# Saving Checkpoint: lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78
# Saving Checkpoint: old_lc_checkpoint_7.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78
# Epoch: 19, Iteration: 29
# Saving Checkpoint: lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_78
# Saving Checkpoint: old_lc_checkpoint_8.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_78
# Epoch: 19, Iteration: 30
# saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_79\base_model.pt
# old_lc | saving full base model @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_79/initial_model.pt
# model accuracy: 0.996
# model accuracy: 0.949
# model accuracy: 0.945
# model accuracy: 0.996
# Full accuracy: 0.996, LC accuracy: 0.996, Decomposed-Full accuracy: 0.949, Decomposed-Restored accuracy: 0.945
# Epoch: 19, Iteration: 31
# Saving Checkpoint: lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/lobranch/set_79
# Saving Checkpoint: old_lc_checkpoint_0.pt @ ./volumes/Ultra Touch/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/old-lc/set_79

# %% [markdown]
# ## For recovery and not restart from scratch : having the plots and the results

# %%
import json

with open(HDFP + "/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/alexnet-data.json") as f:
    data = json.load(f)
full_accuracy = data['full_acc']
lc_accuracy = data["lc_restored_accuracy"]
restored_accuracy = data["decomposed_restored_accuracy"]
decomposed_full_accuracy = data["decomposed_full_accuracy"]

# %% [markdown]
# ### Plotting the results

# %%
plt.figure(figsize = (30, 5))
plt.title("AlexNet, Accuracy, Branched @ {} Accuracy".format(BRANCH_ACC))
plt.plot(full_accuracy, label = "Default AlexNet")
plt.plot(lc_accuracy, label = "LC AlexNet")
plt.plot(decomposed_full_accuracy, label = "dLoRA AlexNet")
plt.plot(restored_accuracy, label = "dLoRA + LC AlexNet")
plt.xticks([x for x in range(0, 120) if x % 6 == 0], [x for x in range(0, 20)])
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
# plt.figure(figsize = (30, 5))
# plt.title("AlexNet, Accuracy, Branched @ {} Accuracy".format(BRANCH_ACC))
# # plt.plot(full_accuracy, label = "Default AlexNet")
# plt.plot(lc_accuracy, label = "LC AlexNet")
# # plt.plot(decomposed_full_accuracy, label = "dLoRA AlexNet")
# # plt.plot(restored_accuracy, label = "dLoRA + LC AlexNet")
# plt.xticks([x for x in range(0, 120) if x % 6 == 0], [x for x in range(0, 20)])
# plt.ylabel("Accuracy")
# plt.xlabel("Epoch")
# plt.legend()
# plt.show()

# %% [markdown]
# ### Plotting the absolute accuracy loss

# %%
rangex = [x for x in np.arange(0, 1, 200) if x % 10 == 0]
rangey = [x for x in np.arange(0, 1, 20)]
plt.figure(figsize = (40, 10))
ax1 = plt.subplot(1, 2, 1)
ax1.set_title("AlexNet Absolute Accuracy Loss (Default AlexNet vs LC AlexNet / LC + dLoRA AlexNet)".format(RANK))
plt.plot(np.abs(np.subtract(np.array(full_accuracy), 
                     np.array(restored_accuracy))), label = "LC + dLoRA AlexNet")
plt.plot(np.abs(np.subtract(np.array(full_accuracy), 
                     np.array(lc_accuracy))), label = "LC AlexNet")
plt.legend()
plt.xticks(rangex, rangey)
plt.ylabel("Absolute Accuracy Loss")
plt.xlabel("Epoch")
plt.axhline(y = 0.05, color = 'r')
plt.ylim(0, 0.5)
ax2 = plt.subplot(1, 2, 2)
ax2.set_title("AlexNet Absolute Restoration Accuracy Loss (LC + dLoRA AlexNet & LC AlexNet)")
plt.plot(np.abs(np.subtract(np.array(restored_accuracy), 
                     np.array(decomposed_full_accuracy))), label = "LC + dLoRA AlexNet")
plt.plot(np.abs(np.subtract(np.array(full_accuracy), 
                     np.array(lc_accuracy))), label = "LC AlexNet")
plt.legend()
plt.axhline(y = 0.05, color = 'r')
plt.ylim(0, 0.5)
plt.xticks(rangex, rangey)
plt.ylabel("Absolute Accuracy Loss")
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# ### Function which compute the size of compressed and uncompressed model

# %%
import math
def getsize(sl):
    dir = [x for x in os.listdir(sl)]
    csize, usize = 0, 0
    for set in dir:
        for f in os.listdir(sl + "/" + set):
            fp = sl + "/{}/{}".format(set, f)
            csize += os.path.getsize(fp)
            usize += 46.8 * math.pow(2, 20)
    return csize, usize,

def getsize_og_lc(sl):
    dir = [x for x in os.listdir(sl)]
    csize, usize = 0, 0
    for set in dir:
        for f in os.listdir(sl + "/" + set):
            fp = sl + "/{}/{}".format(set, f)
            csize += 1.2 * math.pow(2, 20)
            usize += 46.8 * math.pow(2, 20)
        csize += 46.8 * math.pow(2, 20)
    return csize, usize,

# %% [markdown]
# ### Print compression ratio

# %%
compressed_size, uncompressed_size = getsize(SAVE_LOC)
a, b = evaluate_compression(uncompressed_size, compressed_size)
compressed_size, uncompressed_size = getsize(SAVE_LOC_OLC)
a1, b1 = evaluate_compression(uncompressed_size, compressed_size)
compressed_size, uncompressed_size = getsize_og_lc(SAVE_LOC_OLC)
a2, b2 = evaluate_compression(uncompressed_size, compressed_size)

print("LC-Checkpoint + GZIP")
print("Compression Ratio: {}%, Space Savings: {}%".format(a1, b1))
print("LoRA + LC-Checkpoint + GZIP")
print("Compression Ratio: {}%, Space Savings: {}%".format(a, b))
print("LC-Checkpoint")
print("Compression Ratio: {}%, Space Savings: {}%".format(a2, b2))
# Out:
# LC-Checkpoint + GZIP
# Compression Ratio: 634.431%, Space Savings: 84.238%
# LoRA + LC-Checkpoint + GZIP
# Compression Ratio: 23491.97%, Space Savings: 99.574%
# LC-Checkpoint
# Compression Ratio: 663.83%, Space Savings: 84.936%

# %% [markdown]
# ### Store data in a dictionary and save it in a file data.json

# %%
import json
data = {
    "full_acc" : full_accuracy,
    "decomposed_restored_accuracy" : restored_accuracy,
    "decomposed_full_accuracy" : decomposed_full_accuracy,
    "lc_restored_accuracy" : lc_accuracy
}
with open(HDFP + "/lobranch-snapshot/diffbitwidth-adaptive-rank/alexnet/alexnet-data.json", 'w') as f:
    json.dump(data, f)
